# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve

normale = plt.plot([1400,2500,3400,5000,6000,10000,15000,18000,25000,30000,32000,35000,38000],[0.01924,0.03355,0.02289,0.07411,0.04010,0.12071,0.18329,0.24676,0.45335,0.41292,0.30029,0.31010,0.33103] ,color='orange',  linestyle='-', label='normale')
quantum = plt.plot([1400,2500,3400,5000,6000,10000,15000,18000,25000,30000,32000,35000,38000],[0.01474,0.01855,0.01575,0.05169,0.03333,0.08641,0.24876,0.16835,0.18028,0.21254,0.19228,0.19934,0.21439 ] , color='green', linestyle='-', label='quantum')
plt.xlabel('Numero di esempi')
plt.ylabel('Tempo di calcolo')
plt.title('Tempo di calcolo/Numero esempi')
plt.legend(['Nomale', 'Quantum'])
#plt.legend((normale, quantum), ('normale', 'quantum'))
#plt.show()
plt.savefig('tempo.jpg')

# %%
from numpy import mean
normale = [0.01924,0.03355,0.02289,0.07411,0.04010,0.12071,0.18329,0.24676,0.45335,0.41292,0.30029,0.31010,0.33103]
quantum = [0.01474,0.01855,0.01575,0.05169,0.03333,0.08641,0.24876,0.16835,0.18028,0.21254,0.19228,0.19934,0.21439 ]
normale_mean = mean(normale)
quantum_mean = mean(quantum)
print(mean(normale))
print(mean(quantum))
# Out:
# 0.19602615384615385
# 0.12587769230769233

# %%
unperc = normale_mean / 100 
perc = quantum_mean /unperc
print(perc)
# Out:
# 33.72857478281286

# %%
list = [10000,6000,6000,10000,6000]
print(sum(list))
# Out:
# 38000
